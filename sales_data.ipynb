# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('sales_data.csv')

# %%
data.head()
# Out:
#         Date Product Category  Total Sales
# 0 2023-01-05      Electronics         1500
# 1 2023-01-10          Fashion          300
# 2 2023-01-15       Home Decor          750
# 3 2023-01-18         footwear          250
# 4 2023-01-07           fruits          100

# %%
data.tail()
# Out:
#          Date Product Category  Total Sales
# 55 2023-12-05      Electronics         1600
# 56 2023-12-10          Fashion          970
# 57 2023-12-14       Home Decor          840
# 58 2023-12-02         footwear          570
# 59 2023-12-07           fruits          180

# %%
data.count()
# Out:
# Date                60
# Product Category    60
# Total Sales         60
# dtype: int64

# %%
# Convert Date column to datetime, handling errors
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# %%
# Drop rows with missing values in important columns
data.dropna(subset=['Date', 'Total Sales', 'Product Category'], inplace=True)

# %%
data.head()
# Out:
#         Date Product Category  Total Sales
# 0 2023-01-05      Electronics         1500
# 1 2023-01-10          Fashion          300
# 2 2023-01-15       Home Decor          750
# 3 2023-01-18         footwear          250
# 4 2023-01-07           fruits          100

# %%
data.tail()
# Out:
#          Date Product Category  Total Sales
# 55 2023-12-05      Electronics         1600
# 56 2023-12-10          Fashion          970
# 57 2023-12-14       Home Decor          840
# 58 2023-12-02         footwear          570
# 59 2023-12-07           fruits          180

# %%
plt.plot(data.index,data["Total Sales"])

# %%
plt.figure(figsize=(16,10))
plt.xticks
plt.yticks
plt.xlabel("month",fontsize=14)
plt.xlabel("Sales in USD",fontsize=14)
plt.plot(data.index,data["Product Category"])
plt.plot(data.index,data["Total Sales"])

# %%
# Plot Total Sales per Month
plt.figure(figsize=(10, 6))
monthly_sales['Total Sales'].plot(kind='bar', color='skyblue')
plt.title('Total Sales Per Month')
plt.ylabel('Sales in USD')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Sales by Product Category
product_sales = data.groupby('Product Category')['Total Sales'].sum().sort_values(ascending=False)

# Plot Sales Distribution by Product Category as Pie Chart
plt.figure(figsize=(8, 8))
product_sales.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Sales Distribution by Product Category')
plt.ylabel('')
plt.tight_layout()
plt.show()

# Run : python sales_analysis.py
